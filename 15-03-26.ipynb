# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
#from sklearn.model_selection import train_test_split
import random 
name=["ram","shyam","rahul","adarsh","dhoni","paras"]*10
r_roll=np.random.randint(1,101,size=60)
roll=list(r_roll)
a_age=np.random.randint(17,21,size=60)
age=list(a_age)
course=["BTECH","B-PHARMA","BBA","BCA","ABM","BCM"]*10
m_marks=np.random.randint(35,100,size=60)
marks=list(m_marks)
data={'name':name,'roll':roll,'age':age,'course':course,'marks':marks}
df=pd.DataFrame(data)
print(df)
df.to_csv("data1.csv")
# Out:
#       name  roll  age    course  marks
# 0      ram     4   19     BTECH     63
# 1    shyam    54   20  B-PHARMA     73
# 2    rahul    71   20       BBA     58
# 3   adarsh    43   18       BCA     95
# 4    dhoni    49   17       ABM     75
# 5    paras    42   17       BCM     43
# 6      ram    76   18     BTECH     67
# 7    shyam    10   18  B-PHARMA     70
# 8    rahul    12   19       BBA     59
# 9   adarsh     7   20       BCA     88
# 10   dhoni    66   18       ABM     65
# 11   paras    99   19       BCM     69
# 12     ram    60   20     BTECH     98
# 13   shyam    24   17  B-PHARMA     41
# 14   rahul    11   20       BBA     69
# 15  adarsh    10   18       BCA     71
# 16   dhoni    55   19       ABM     72
# 17   paras    65   19       BCM     64
# 18     ram    14   19     BTECH     40
# 19   shyam    15   17  B-PHARMA     75
# 20   rahul    79   20       BBA     41
# 21  adarsh    59   19       BCA     66
# 22   dhoni    82   18       ABM     37
# ...

# %%
print(df)
df.to_csv("data1.csv")
# Out:
#       name  roll  age    course  marks
# 0      ram     4   19     BTECH     63
# 1    shyam    54   20  B-PHARMA     73
# 2    rahul    71   20       BBA     58
# 3   adarsh    43   18       BCA     95
# 4    dhoni    49   17       ABM     75
# 5    paras    42   17       BCM     43
# 6      ram    76   18     BTECH     67
# 7    shyam    10   18  B-PHARMA     70
# 8    rahul    12   19       BBA     59
# 9   adarsh     7   20       BCA     88
# 10   dhoni    66   18       ABM     65
# 11   paras    99   19       BCM     69
# 12     ram    60   20     BTECH     98
# 13   shyam    24   17  B-PHARMA     41
# 14   rahul    11   20       BBA     69
# 15  adarsh    10   18       BCA     71
# 16   dhoni    55   19       ABM     72
# 17   paras    65   19       BCM     64
# 18     ram    14   19     BTECH     40
# 19   shyam    15   17  B-PHARMA     75
# 20   rahul    79   20       BBA     41
# 21  adarsh    59   19       BCA     66
# 22   dhoni    82   18       ABM     37
# ...

# %%
df=pd.read_csv("data1.csv")
df
# Out:
#     Unnamed: 0    name  roll  age    course  marks
# 0            0     ram     4   19     BTECH     63
# 1            1   shyam    54   20  B-PHARMA     73
# 2            2   rahul    71   20       BBA     58
# 3            3  adarsh    43   18       BCA     95
# 4            4   dhoni    49   17       ABM     75
# 5            5   paras    42   17       BCM     43
# 6            6     ram    76   18     BTECH     67
# 7            7   shyam    10   18  B-PHARMA     70
# 8            8   rahul    12   19       BBA     59
# 9            9  adarsh     7   20       BCA     88
# 10          10   dhoni    66   18       ABM     65
# 11          11   paras    99   19       BCM     69
# 12          12     ram    60   20     BTECH     98
# 13          13   shyam    24   17  B-PHARMA     41
# 14          14   rahul    11   20       BBA     69
# 15          15  adarsh    10   18       BCA     71
# 16          16   dhoni    55   19       ABM     72
# ...

# %%
plt.scatter(df['age'],df['roll'])
plt.xlabel('age')
plt.ylabel('roll')
plt.title('age vs roll')
plt.show()

# %%
x=(df['age'])
x
# Out:
# 0     19
# 1     20
# 2     20
# 3     18
# 4     17
# 5     17
# 6     18
# 7     18
# 8     19
# 9     20
# 10    18
# 11    19
# 12    20
# 13    17
# 14    20
# 15    18
# 16    19
# 17    19
# 18    19
# 19    17
# 20    20
# 21    19
# 22    18
# 23    20
# 24    19
# 25    19
# 26    18
# 27    17
# 28    18
# 29    18
# 30    18
# 31    19
# 32    18
# 33    20
# 34    18
# 35    17
# 36    17
# 37    17
# 38    20
# 39    19
# 40    20
# 41    18
# 42    20
# 43    17
# 44    17
# 45    19
# 46    20
# 47    18
# 48    17
# 49    18
# 50    17
# 51    17
# 52    20
# 53    17
# 54    17
# 55    17
# 56    17
# 57    17
# 58    18
# 59    20
# Name: age, dtype: int64

# %%
y=(df['roll'])
y
# Out:
# 0      4
# 1     54
# 2     71
# 3     43
# 4     49
# 5     42
# 6     76
# 7     10
# 8     12
# 9      7
# 10    66
# 11    99
# 12    60
# 13    24
# 14    11
# 15    10
# 16    55
# 17    65
# 18    14
# 19    15
# 20    79
# 21    59
# 22    82
# 23    33
# 24    40
# 25    69
# 26    97
# 27    65
# 28    51
# 29    27
# 30     6
# 31    22
# 32    40
# 33     6
# 34    70
# 35    64
# 36    28
# 37    97
# 38    10
# 39    13
# 40    16
# 41    33
# 42    43
# 43     5
# 44    72
# 45     2
# 46     5
# 47    95
# 48    21
# 49    47
# 50    13
# 51    30
# 52    32
# 53    67
# 54    23
# 55    22
# 56    84
# 57    97
# 58    96
# 59    13
# Name: roll, dtype: int64

# %%
z=df['roll']
z=np.array(z).reshape(-1,1)
z
# Out:
# array([[ 4],
#        [54],
#        [71],
#        [43],
#        [49],
#        [42],
#        [76],
#        [10],
#        [12],
#        [ 7],
#        [66],
#        [99],
#        [60],
#        [24],
#        [11],
#        [10],
#        [55],
#        [65],
#        [14],
#        [15],
#        [79],
#        [59],
#        [82],
#        [33],
#        [40],
#        [69],
#        [97],
#        [65],
#        [51],
#        [27],
#        [ 6],
#        [22],
#        [40],
#        [ 6],
#        [70],
#        [64],
#        [28],
#        [97],
#        [10],
#        [13],
#        [16],
#        [33],
#        [43],
#        [ 5],
#        [72],
#        [ 2],
#        [ 5],
#        [95],
#        [21],
#        [47],
#        [13],
#        [30],
#        [32],
#        [67],
#        [23],
#        [22],
#        [84],
#        [97],
#        [96],
#        [13]])

# %%
q=df['age']
q=np.array(q).reshape(-1,1)
q
# Out:
# array([[19],
#        [20],
#        [20],
#        [18],
#        [17],
#        [17],
#        [18],
#        [18],
#        [19],
#        [20],
#        [18],
#        [19],
#        [20],
#        [17],
#        [20],
#        [18],
#        [19],
#        [19],
#        [19],
#        [17],
#        [20],
#        [19],
#        [18],
#        [20],
#        [19],
#        [19],
#        [18],
#        [17],
#        [18],
#        [18],
#        [18],
#        [19],
#        [18],
#        [20],
#        [18],
#        [17],
#        [17],
#        [17],
#        [20],
#        [19],
#        [20],
#        [18],
#        [20],
#        [17],
#        [17],
#        [19],
#        [20],
#        [18],
#        [17],
#        [18],
#        [17],
#        [17],
#        [20],
#        [17],
#        [17],
#        [17],
#        [17],
#        [17],
#        [18],
#        [20]])

# %%
from sklearn.model_selection import train_test_split

# %%
#z=df[['age']]
#y=df[['roll']]
z_train,z_test,q_train,q_test=train_test_split(z,q,test_size=0.2)
z_train,z_test,q_train,q_test
# Out:
# (array([[ 7],
#         [ 5],
#         [13],
#         [79],
#         [70],
#         [64],
#         [65],
#         [43],
#         [76],
#         [99],
#         [71],
#         [43],
#         [84],
#         [22],
#         [10],
#         [67],
#         [16],
#         [40],
#         [13],
#         [30],
#         [97],
#         [28],
#         [54],
#         [97],
#         [47],
#         [97],
#         [69],
#         [ 2],
#         [10],
#         [12],
#         [23],
#         [33],
#         [ 6],
#         [42],
#         [96],
#         [55],
#         [95],
#         [65],
#         [40],
#         [13],
#         [ 4],
#         [82],
#         [ 5],
#         [10],
#         [15],
#         [60],
#         [21],
#         [22]]),
#  array([[32],
#         [66],
#         [72],
#         [27],
#         [33],
#         [24],
#         [49],
#         [ 6],
#         [59],
#         [11],
#         [14],
#         [51]]),
#  array([[20],
#         [17],
# ...

# %%
model=LinearRegression()
model.fit(z_train,q_train)
# Out:
# LinearRegression()

# %%
q_pred=model.predict(z_train)
q_pred
# Out:
# array([[18.49946905],
#        [18.50954711],
#        [18.46923487],
#        [18.13665881],
#        [18.18201009],
#        [18.21224428],
#        [18.20720524],
#        [18.31806393],
#        [18.1517759 ],
#        [18.03587818],
#        [18.17697106],
#        [18.31806393],
#        [18.11146365],
#        [18.42388358],
#        [18.48435196],
#        [18.19712718],
#        [18.45411777],
#        [18.33318102],
#        [18.46923487],
#        [18.38357134],
#        [18.04595625],
#        [18.3936494 ],
#        [18.26263459],
#        [18.04595625],
#        [18.29790781],
#        [18.04595625],
#        [18.18704912],
#        [18.52466421],
#        [18.48435196],
#        [18.4742739 ],
#        [18.41884455],
#        [18.36845424],
#        [18.50450808],
#        [18.32310296],
#        [18.05099528],
#        [18.25759556],
#        [18.05603431],
#        [18.20720524],
#        [18.33318102],
#        [18.46923487],
#        [18.51458615],
# ...

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

q_pred=model.predict(z_test)
q_pred#print(f"Accuracy: {accuracy_score(q_test,q_pred):.4f}")
